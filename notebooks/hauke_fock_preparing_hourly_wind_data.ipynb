# %%
# imports

import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/mnt/g/Meine Ablage/raw_data/Features/Wind speed/Hourly/data/data_OBS_DEU_PT1H_F.csv", delimiter = ",",names=["Product_Code","Station_ID","Time_Stamp","Value","Quality_Byte","Quality"])
# Out:
# /home/hauke/.pyenv/versions/3.8.6/envs/predict_energy_generation/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (1,3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head
# Out:
# <bound method NDFrame.head of             Product_Code Station_ID           Time_Stamp Value  \
# 0           Produkt_Code     SDO_ID          Zeitstempel  Wert
# 1         OBS_DEU_PT1H_F       1001  2015-01-01T00:00:00   2.2
# 2         OBS_DEU_PT1H_F       1001  2015-01-01T01:00:00   2.5
# 3         OBS_DEU_PT1H_F       1001  2015-01-01T02:00:00   2.6
# 4         OBS_DEU_PT1H_F       1001  2015-01-01T03:00:00   2.8
# ...                  ...        ...                  ...   ...
# 15605450  OBS_DEU_PT1H_F        963  2021-04-30T19:00:00   1.5
# 15605451  OBS_DEU_PT1H_F        963  2021-04-30T20:00:00   3.9
# 15605452  OBS_DEU_PT1H_F        963  2021-04-30T21:00:00   2.2
# 15605453  OBS_DEU_PT1H_F        963  2021-04-30T22:00:00   0.8
# 15605454  OBS_DEU_PT1H_F        963  2021-04-30T23:00:00   0.8
#
#             Quality_Byte           Quality
# 0         Qualitaet_Byte  Qualitaet_Niveau
# 1                      4                10
# 2                      4                10
# 3                      4                10
# 4                      4                10
# ...                  ...               ...
# 15605450               4                 1
# 15605451               4                 1
# 15605452               4                 1
# 15605453               4                 1
# 15605454               4                 1
#
# [15605455 rows x 6 columns]>

# %%
# Dropping Produkt_Code and Quality_Byte because they hold no nominal values
# Also Dropping Quality for now,We could possibly test if the Quality of data makes a difference and drop the Quality
data = data.drop(columns=["Product_Code", "Quality_Byte", "Quality"])

# %%
data = data.drop(data.index[0])

# %%
data["Date"] = pd.to_datetime(data["Time_Stamp"])
data.drop(columns = ["Time_Stamp"])
# Out:
#          Station_ID Value                Date
# 1              1001   2.2 2015-01-01 00:00:00
# 2              1001   2.5 2015-01-01 01:00:00
# 3              1001   2.6 2015-01-01 02:00:00
# 4              1001   2.8 2015-01-01 03:00:00
# 5              1001   2.8 2015-01-01 04:00:00
# ...             ...   ...                 ...
# 15605450        963   1.5 2021-04-30 19:00:00
# 15605451        963   3.9 2021-04-30 20:00:00
# 15605452        963   2.2 2021-04-30 21:00:00
# 15605453        963   0.8 2021-04-30 22:00:00
# 15605454        963   0.8 2021-04-30 23:00:00
#
# [15605454 rows x 3 columns]

# %%
#Froming the Dataframe
df_pivot_values = data.pivot(index="Date", columns="Station_ID", values="Value")

# %%
# Drops timeseries of weather stations with more than 5% NAN values
df_pivot_values = df_pivot_values.dropna(axis=1, thresh=df_pivot_values.shape[0]*0.95)

# %%
# Filling remainig NAN
for column in df_pivot_values.columns:
    df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# Out:
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())
# <ipython-input-17-fdeb927eb5e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_values[column] = df_pivot_values[column].fillna((df_pivot_values[column]).median())

# %%
df_pivot_values.isna().sum().sum()
# Out:
# 0

# %%
# saving Dataframe to Google Drive
df_pivot_values.to_csv("/mnt/g/Meine Ablage/raw_data/Features/DATAFRAMES/wind_hourly_clean.csv")

# %%
df_pivot_values
# Out:
# Station_ID            90  125  161  164   183  197  198  232  282  298  ...  \
# Date                                                                    ...
# 2015-01-01 00:00:00  2.1  0.7  0.9  5.1  11.3  3.2  1.6  1.1  0.7  7.0  ...
# 2015-01-01 01:00:00  2.7  0.3  0.8  4.9  13.0  3.2  2.6  1.5  0.9  7.4  ...
# 2015-01-01 02:00:00  2.5  0.8  1.3  3.9  12.8  3.2  3.2  1.7  0.9  7.1  ...
# 2015-01-01 03:00:00  2.0  0.7  1.4  3.7  12.4  3.2  3.5  1.5  0.6  6.9  ...
# 2015-01-01 04:00:00  1.1  0.9  1.7  4.2  12.2  3.2  3.4  1.7  1.0  6.0  ...
# ...                  ...  ...  ...  ...   ...  ...  ...  ...  ...  ...  ...
# 2021-04-30 19:00:00  0.8  3.0  1.8  2.6   1.9  1.7  3.0  3.8  1.3  1.5  ...
# 2021-04-30 20:00:00  0.9  1.9  1.3  2.2   2.7  0.6  2.5  2.9  1.3  2.1  ...
# 2021-04-30 21:00:00  0.9  0.8  1.1  1.9   2.9  0.6  1.6  2.7  1.3  1.7  ...
# 2021-04-30 22:00:00  0.7  0.7  3.1  1.7   1.1  0.7  1.3  2.6  1.3  2.4  ...
# 2021-04-30 23:00:00  0.5  0.9  1.8  1.4   1.9  1.6  1.8  2.2  1.0  1.9  ...
#
# Station_ID           15000  15044  15120  15122  15189  15200  15207  15214  \
# Date
# 2015-01-01 00:00:00    3.9    0.8    4.9    3.2    4.4    3.0    0.5    1.2
# 2015-01-01 01:00:00    3.4    0.7    5.3    2.6    6.0    2.8    0.8    1.1
# 2015-01-01 02:00:00    3.8    1.3    4.8    2.3    5.7    3.1    0.5    1.8
# 2015-01-01 03:00:00    4.2    1.1    4.2    2.5    5.4    3.2    0.7    1.1
# 2015-01-01 04:00:00    4.4    0.9    4.1    1.8    6.1    3.6    0.8    0.9
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 2021-04-30 19:00:00    3.3    2.0    1.3    2.2    1.9    0.9    1.9    1.6
# 2021-04-30 20:00:00    2.5    2.1    1.8    3.2    1.5    1.0    1.5    1.3
# 2021-04-30 21:00:00    2.4    1.4    2.7    2.4    1.4    1.2    1.6    1.7
# 2021-04-30 22:00:00    2.0    3.8    3.0    2.8    1.3    1.1    0.9    1.1
# 2021-04-30 23:00:00    2.2    3.6    3.3    2.0    1.2    1.6    0.7    1.4
#
# Station_ID           15444  1001
# Date
# 2015-01-01 00:00:00    1.0   2.2
# 2015-01-01 01:00:00    1.0   2.5
# 2015-01-01 02:00:00    1.2   2.6
# 2015-01-01 03:00:00    1.0   2.8
# 2015-01-01 04:00:00    1.4   2.8
# ...                    ...   ...
# 2021-04-30 19:00:00    1.3   1.6
# 2021-04-30 20:00:00    1.1     2
# 2021-04-30 21:00:00    1.1   1.2
# 2021-04-30 22:00:00    0.9   1.7
# 2021-04-30 23:00:00    0.7     2
#
# [55488 rows x 260 columns]
